# %% [markdown]
# <a href="https://colab.research.google.com/github/Molal/sharing/blob/main/Assignment9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_name = "electricity.txt"
file1=open(file_name, "a+")
file1.close

def kplc_main_menu():
    '''Charges for Elecricity per kilowatt'''
    print("*** KENYA POWER & LIGHTING COMPANY DATABASE ***\n" + 
         "Owner of the Programme: Olal Darick Jnr \n"+
         "--------------------------------------------\n" +
         "Enter 1, 2, or 3: \n" +
         "Enter 1 Rural Areas \n" +
         "Enter 2 Urban Areas \n" +
         "Enter 3 to Quite \n*****************************************")
    choice = input("Enter your choice: ")
    if choice == "1":
        rural_areas()
        ent=input("Press Enter to continue ...")
        kplc_main_menu()
    elif choice == "2":
        urban_areas()
        ent=input("Press Enter to continue ...")
        kplc_main_menu()
    elif choice == "3":
        print("Thanks for your cooperation, and We Value you our Dear Customer")     
    else:
        print("Invalid Option\n") 
        ent=input("Press enter to continue ...")
        kplc_main_menu()
        return
        file1=open(file_name, "a")
        file1.write(electricity)
        file1.close()
        
def rural_areas():
    print("Enter RR, RL or RH \n" +
          "Enter RR for Rural Residents \n" +
          "Enter RL for Rural Light Industrial \n" +
          "Enter RH for Rural Heavy Industrial \n")
    choice=input("Enter your choice: ")
    first_name=input("Customer's First Name: ")
    last_name=input("Customer's Last Name: ")
    customer_fullname=(first_name + " " + last_name)
    mobile_no=input("Mobile No : ")
    email_address=input("Email Address : ")
    county=input("County : ")
    city=input("City : ")
    town=input("Town : ")
    billing_address=input("Billing Address: ")
    full_address=(customer_fullname + ", " + mobile_no + ", " + email_address + ", "  + county + ", " + city + ", " + town + ", " + billing_address)
       
    if choice == "RR":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 10
            vat=charge * 0.1
            discount=vat*0.03
        elif (units>451 and units <= 500):
            charge=(450*10) + (units - 450)*10
            vat=charge * 0.1
            discount=vat*0.05
        elif (units>501 and units <= 601):
            charge=(450*10)+(500-450)*10 + (units - 500)*10
            vat=charge * 0.1
            discount=vat*0.07
        elif (units>602 and units <= 701):
            charge=(450*10)+(601-500)*10+(500-450)*10 + (units - 601)*10
            vat=charge * 0.1
            discount=vat*0.09
        elif (units>702 and units <= 801):
            charge=(450*10)+(701-601)*10+(601-500)*10 +(500-450)*10 + (units - 701)*10
            vat=charge * 0.1
            discount=vat*0.11
        elif (units>802):
            charge=(450*10)+(801-701)*10+(701-601)*10 + (601-500)*10 +(500-450)*10 + (units - 801)*10
            vat=charge * 0.1
            discount=vat*0.12
        else:
            charge=0
            vat=units * 0.1   
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Resident in Rural areas = %.2f"%Total)

    if choice == "RL":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 20
            vat=charge * 0.15
            discount=vat * 0.03
        elif (units>451 and units <= 500):
            charge=(450*20) + (units - 450)*20
            vat= charge * 0.15
            discount=vat * 0.05
        elif (units>501 and units <= 601):
            charge=(450*20)+(500-450)*20 + (units - 500)*20
            vat=charge * 0.15
            discount=vat * 0.07
        elif (units>602 and units <= 701):
            charge=(450*20)+(601-500)*20+(500-450)*20 + (units - 601)*20
            vat=charge * 0.15
            discount=vat * 0.09
        elif (units>702 and units <= 801):
            charge=(450*20)+(701-601)*20+(601-500)*20 +(500-450)*20 + (units - 701)*20
            vat=charge * 0.15
            discount=vat * 0.11
        elif (units>802):
            charge=(450*20)+(801-701)*20 + (701-601)*20 + (601-500)*20 +(500-450)*20 + (units - 801)*20
            vat=charge * 0.15
            discount=vat * 0.12
        else:
            charge=0
            vat=charge * 0.15
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Light Industries in Rural Areas = %.2f"% Total)

        
    if choice == "RH":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 27
            vat=charge * 0.15
            discount=vat * 0.03
        elif (units>451 and units <= 500):
            charge=(450*27) + (units - 450)*27
            vat=charge * 0.15
            discount=vat * 0.05
        elif (units>501 and units <= 601):
            charge=(450*27)+(500-450)*27 + (units - 500)*27
            vat=charge * 0.15
            discount=vat * 0.07
        elif (units>602 and units <= 701):
            charge=(450*27)+(601-500)*27+(500-450)*27 + (units - 601)*27
            vat=charge * 0.15
            discount=vat * 0.09
        elif (units>702 and units <= 801):
            charge=(450*27)+(701-601)*27 + (601-500)*27 +(500-450)*27 + (units - 701)*27
            vat=charge * 0.15
            discount=vat * 0.11
        elif (units>802):
            charge=(450*27)+(801-701)*27+(701-601)*27 + (601-500) +(500-450)*27 + (units - 801)*27
            vat=charge * 0.15
            discount=vat * 0.12
        else:
            charge=0
            vat=charge * 0.1
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Heavy Industries in Rural Areas = %.2f"% Total)     

def urban_areas():
    print("Enter UR, UL or UH \n" +
          "Enter UR for Urban Residents \n" +
          "Enter UL for Urban Light Industrial \n" +
          "Enter UH for Urban Heavy Industrial \n")
    choice=input("Enter your choice: ")  
    first_name=input("Customer's First Name: ")
    last_name=input("Customer's Last Name: ")
    customer_fullname=(first_name + " " + last_name)
    mobile_no=input("Mobile No : ")
    email_address=input("Email Address : ")
    county=input("County : ")
    city=input("City : ")
    town=input("Town : ")
    billing_address=input("Billing Address: ")
    full_address=(customer_fullname + ", " + mobile_no + ", " + email_address + ", "  + county + ", " + city + ", " + town + ", " + billing_address)
      
    if choice == "UR":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 15
            vat=charge * 0.1
            discount=vat * 0.03
        elif (units>451 and units <= 500):
            charge=(450*15) + (units - 450)*15
            vat=charge * 0.1
            discount=vat * 0.05
        elif (units>501 and units <= 601):
            charge=(450*15)+(500-450)*15 + (units - 500)*15
            vat=charge * 0.1
            discount=vat * 0.07
        elif (units>602 and units <= 701):
            charge=(450*15)+(601-500)*15 + (500-450)*15 + (units - 601)*15
            vat=charge * 0.1
            discount=vat * 0.09
        elif (units>702 and units <= 801):
            charge=(450*15)+(701-601)*15 + (601-500)*15 +(500-450)*15 + (units - 701)*15
            vat=charge * 0.1
            discount=vat * 0.11
        elif (units>802):
            charge=(450*15)+(801-701)*15 + (701-601)*15 + (601-500)*15 +(500-450)*15 + (units - 801)*15
            vat=charge * 0.1
            discount=vat * 0.12
        else:
            charge=0
            vat=charge * 0.1
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Residents in Urban Areas = %.2f"%Total)

        
    if choice == "UL":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 23
            vat=charge * 0.18
            discount=vat * 0.03
        elif (units>451 and units <= 500):
            charge=(450*23) + (units - 450)*23
            vat=charge * 0.18
            discount=vat * 0.05
        elif (units>501 and units <= 601):
            charge=(450*23)+(500-450)*23 + (units - 500)*23
            vat=charge * 0.18
            discount=vat * 0.07
        elif (units>602 and units <= 701):
            charge=(450*23)+(601-500)*23 + (500-450)*23 + (units - 601)*23
            vat=charge * 0.18
            discount=vat * 0.09
        elif (units>702 and units <= 801):
            charge=(450*23)+(701-601)*23+(601-500)*23 +(500-450)*23 + (units - 701)*23
            vat=charge * 0.18
            discount=vat * 0.11
        elif (units>802):
            charge=(450*23)+(801-701)*23 + (701-601)*23 + (601-500)*23 +(500-450)*23 + (units - 801)*23
            vat=charge * 0.18
            discount=vat * 0.12
        else:
            charge=0
            vat=charge * 0.18
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Light Industries in Urban Areas = %.2f"% Total)

        
    if choice == "UH":
        units=int(input("Enter number of Units consumed in a month: "))
        if (units>200 and units<= 450):
            charge=units * 30
            vat=charge * 0.18
            discount=vat * 0.03
        elif (units>451 and units <= 500):
            charge=(450*30) + (units - 450)*30
            vat=charge * 0.18
            discount=vat * 0.05
        elif (units>501 and units <= 601):
            charge=(450*30)+(500-450)*30 + (units - 500)*30
            vat=charge * 0.18
            discount=vat * 0.07
        elif (units>602 and units <= 701):
            charge=(450*30)+(601-500)*30 + (500-450)*30 + (units - 601)*30
            vat=charge * 0.18
            discount=vat * 0.09
        elif (units>702 and units <= 801):
            charge=(450*30)+(701-601)*30 + (601-500)*30 +(500-450)*30 + (units - 701)*30
            vat=charge * 0.18
            discount=vat * 0.11
        elif (units>802):
            charge=(450*30)+(801-701)*30 + (701-601)*30 + (601-500) +(500-450)*30 + (units - 801)*30
            vat=charge * 0.18
            discount=vat * 0.12
        else:
            charge=0
            vat=charge * 0.1
        sub_total=charge + vat
        Total=sub_total - discount
        print()
        print("Customer's Name: " + customer_fullname)
        print("Customer's Full Address: " + full_address)
        print("Discount : ", discount)
        print("Electricity Bill for Heavy Industries in Urban Areas = %.2f"% Total)
    
kplc_main_menu()
# Out:
# *** KENYA POWER & LIGHTING COMPANY DATABASE ***
# Owner of the Programme: Olal Darick Jnr
# --------------------------------------------
# Enter 1, 2, or 3:
# Enter 1 Rural Areas
# Enter 2 Urban Areas
# Enter 3 to Quite
# *****************************************
# Enter your choice: 1
# Enter RR, RL or RH
# Enter RR for Rural Residents
# Enter RL for Rural Light Industrial
# Enter RH for Rural Heavy Industrial
#
# Enter your choice: BR
# Customer's First Name:  ELVIS
# Customer's Last Name:  WAGA
# Mobile No :  0723887642
# Email Address : 658
# County :  Nairobi
# City :  Nairobi
# Town :  Westlands
# Billing Address:  accra road
# Press Enter to continue ...
# *** KENYA POWER & LIGHTING COMPANY DATABASE ***
# Owner of the Programme: Olal Darick Jnr
# --------------------------------------------
# Enter 1, 2, or 3:
# Enter 1 Rural Areas
# Enter 2 Urban Areas
# Enter 3 to Quite
# *****************************************
# Enter your choice: YR
# Invalid Option
#
# ...
